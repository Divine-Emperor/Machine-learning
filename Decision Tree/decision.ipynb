# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# 📌 Step 1: Create a simple dataset
data = {
    'weather': ['sunny', 'rainy', 'overcast', 'sunny', 'rainy', 'overcast', 'sunny', 'rainy'],
    'temperature': ['hot', 'cold', 'mild', 'hot', 'cold', 'mild', 'hot', 'cold'],
    'go_outside': ['yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'no']  # Target variable
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     weather temperature go_outside
# 0     sunny         hot        yes
# 1     rainy        cold         no
# 2  overcast        mild        yes
# 3     sunny         hot        yes
# 4     rainy        cold         no
# 5  overcast        mild        yes
# 6     sunny         hot        yes
# 7     rainy        cold         no

# %%
# 📌 Step 2: Convert categorical features into numbers
df['weather'] = df['weather'].replace({'sunny': 0, 'rainy': 1, 'overcast': 2})
df['temperature'] = df['temperature'].replace({'hot': 0, 'cold': 1, 'mild': 2})
df['go_outside'] = df['go_outside'].replace({'yes': 1, 'no': 0})
# Out:
# /tmp/ipykernel_18046/2528204484.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['weather'] = df['weather'].replace({'sunny': 0, 'rainy': 1, 'overcast': 2})
# /tmp/ipykernel_18046/2528204484.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['temperature'] = df['temperature'].replace({'hot': 0, 'cold': 1, 'mild': 2})
# ...

# %%
df
# Out:
#    weather  temperature  go_outside
# 0        0            0           1
# 1        1            1           0
# 2        2            2           1
# 3        0            0           1
# 4        1            1           0
# 5        2            2           1
# 6        0            0           1
# 7        1            1           0

# %%
# 📌 Step 3: Features & Target
X = df[['weather', 'temperature']]
y = df['go_outside']

# %%
# 📌 Step 4: Train Decision Tree
clf = DecisionTreeClassifier(max_depth=2, random_state=42)
clf.fit(X, y)

# 📌 Step 5: Visualize Decision Tree
plt.figure(figsize=(10, 4))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()

# %%
df
# Out:
#    weather  temperature  go_outside
# 0        0            0           1
# 1        1            1           0
# 2        2            2           1
# 3        0            0           1
# 4        1            1           0
# 5        2            2           1
# 6        0            0           1
# 7        1            1           0
